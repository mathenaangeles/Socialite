# %%
import os
import json
import datetime
import requests
from dotenv import load_dotenv
import pandas as pd

load_dotenv(dotenv_path='../server/.env')
API_KEY = os.getenv("RAPIDAPI_KEY")
API_HOST = os.getenv("TIKTOK_API_HOST")

if API_KEY is None:
    print("🚨 API_KEY is not set! Make sure you've added it to your environment variables.")
else:
    print(f"API_KEY loaded: {API_KEY[:5]}****")
# Out:
# API_KEY loaded: 3fd67****

# %%
LOG_DIR = "api_usage"
LOG_FILE = os.path.join(LOG_DIR, "tiktok_api_usage.log")

def log_api_usage(endpoint=None, response_status=None, remaining_calls=None):
    """Logs API calls with timestamp, endpoint, response status, and remaining calls."""
    
    # Ensure log directory exists
    os.makedirs(LOG_DIR, exist_ok=True)

    with open(LOG_FILE, "a") as f:
        timestamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        log_entry = f"{timestamp} - API call made"
        
        if endpoint:
            log_entry += f" | Endpoint: {endpoint}"
        if response_status:
            log_entry += f" | Status: {response_status}"
        if remaining_calls is not None:
            log_entry += f" | Remaining Calls: {remaining_calls}"
        
        f.write(log_entry + "\n")

# %%
url = "https://tiktok-scraper7.p.rapidapi.com/"
def get_tiktok_trending(api_key, count=1):
    url_trending = url + "feed/list"
    
    headers = {
        "X-RapidAPI-Key": api_key,
        "X-RapidAPI-Host": API_HOST
    }
    params = {"region":"gb","count":count}
     # Control API usage

    response = requests.get(url_trending, headers=headers, params=params)
    
    if response.status_code == 200:
        return response
    else:
        print(f"Error {response.status_code}: {response.text}")
        return None

# Test with 1 call
response = get_tiktok_trending(API_KEY, count=1)
data = response.json()
data = data["data"]

# Log API usage
log_api_usage(endpoint=url, response_status=response.status_code)
print(data)
# Out:
# [{'aweme_id': 'v24044gl0000cum6hp7og65ijef92k7g', 'video_id': '7470462714754731286', 'region': 'GB', 'title': 'Gym video 💪#gym #uk #mzaidyt❤ #usa #tableeghijumat #viral #treanding #pyf ', 'cover': 'https://p16-pu-sign-no.tiktokcdn-eu.com/tos-no1a-p-0037-no/oUQYjNekPQIZIHLK1DWL49HIQpGFbdAFJAeeJn~tplv-tiktok-shrink:640:640.jpeg?dr=14571&nonce=71724&refresh_token=6d40c6c1427cd1ae968fd5a0797811f7&x-expires=1741878000&x-signature=G3tknnu5DP6%2FV3UP2vqIBTClads%3D&idc=maliva&ps=13740610&s=FEED&shcp=34ff8df6&shp=d05b14bd&t=4d5b0474', 'ai_dynamic_cover': 'https://p16-pu-sign-no.tiktokcdn-eu.com/tos-no1a-p-0037-no/oUQYjNekPQIZIHLK1DWL49HIQpGFbdAFJAeeJn~tplv-tiktok-shrink:640:640.jpeg?dr=14571&nonce=71724&refresh_token=6d40c6c1427cd1ae968fd5a0797811f7&x-expires=1741878000&x-signature=G3tknnu5DP6%2FV3UP2vqIBTClads%3D&idc=maliva&ps=13740610&s=FEED&shcp=34ff8df6&shp=d05b14bd&t=4d5b0474', 'origin_cover': 'https://p16-pu-sign-no.tiktokcdn-eu.com/tos-no1a-p-0037-no/o4IG8Gx9IaeEgSLAPfQApqNebHKjDJIWxgLinF~tplv-tiktokx-360p.webp?dr=14555&nonce=66960&refresh_token=393cb13f03be150b597a47f0803632ea&x-expires=1741878000&x-signature=S2sIkawdbduAs9IGMsquigOzg2Y%3D&ftpl=1&idc=maliva&ps=13740610&s=FEED&shcp=34ff8df6&shp=d05b14bd&t=4d5b0474', 'duration': 142, 'play': 'https://v16m-default.akamaized.net/3833644289a527c8609c7ee94ed07295/67d1f81c/video/tos/no1a/tos-no1a-ve-0068-no/oUeIpaFpgbKIIcWDQsEGeL8jHJALASNAfj2PRn/?a=30192&bti=OHYpOTY0Zik3OjlmOm01MzE6ZDQ0MDo%3D&ch=0&cr=13&dr=0&er=0&lr=all&net=0&cd=0%7C0%7C0%7C&cv=1&br=1798&bt=899&cs=0&ds=6&ft=XE5bCqT0mmjPD120kXTJ3wUp5jB7EeF~O5&mime_type=video_mp4&qs=0&rc=OzM7OmVoOTVnNTs3ZmRnNEBpam48aGw5cnM5eDMzbzczNUAxYTYwXy5hXmAxNDBhX2EyYSM0L2NnMmQ0ZWpgLS1kMTFzcw%3D%3D&vvpl=1&l=2025031215072440B458E665B13A0B5FD1&btag=e00090000', 'wmplay': 'https://v16m-default.akamaized.net/6b0789c83d9b92c378ce8967a13b338b/67d1f81c/video/tos/no1a/tos-no1a-ve-0068c001-no/oYZQBZ6Sx5B7ionIQosm6ByPERaEAPiYZZU5U/?a=30192&bti=OHYpOTY0Zik3OjlmOm01MzE6ZDQ0MDo%3D&ch=0&cr=13&dr=0&er=0&lr=all&net=0&cd=0%7C0%7C0%7C&cv=1&br=1876&bt=938&cs=0&ds=3&ft=XE5bCqT0mmjPD120kXTJ3wUp5jB7EeF~O5&mime_type=video_mp4&qs=0&rc=ODVkODU8Omk5aWQ6OTg1aEBpam48aGw5cnM5eDMzbzczNUAxNTBhXy4tNV4xLjZfLl8uYSM0L2NnMmQ0ZWpgLS1kMTFzcw%3D%3D&vvpl=1&l=2025031215072440B458E665B13A0B5FD1&btag=e00090000', 'size': 16408401, 'wm_size': 17109570, 'music': '', 'music_info': {'id': '7183714413009406746', 'title': 'original sound - bakht.7', 'play': '', 'cover': 'https://p16-sign-useast2a.tiktokcdn.com/tos-useast2a-avt-0068-giso/448342aef25fcc6335b2554cd2214995~tplv-tiktokx-cropcenter:1080:1080.jpeg?dr=14579&nonce=98236&refresh_token=afe4355cf1c820971343bc1e1e2a2fc0&x-expires=1741878000&x-signature=GExOJJQ76k3kpi9wn6dxA8iy0lI%3D&idc=maliva&ps=13740610&shcp=d05b14bd&shp=45126217&t=4d5b0474', 'author': '🥀', 'original': True, 'duration': 443, 'album': ''}, 'play_count': 19306352, 'digg_count': 1818407, 'comment_count': 56711, 'share_count': 39129, 'download_count': 30007, 'create_time': 1739352649, 'anchors': None, 'anchors_extras': '', 'is_ad': False, 'commerce_info': {'adv_promotable': False, 'branded_content_type': 0}, 'commercial_video_info': '', 'item_comment_settings': 0, 'mentioned_users': '', 'author': {'id': '7270758105071502368', 'unique_id': '0ur_vinse', 'nickname': 'ourvinse fanpage', 'avatar': 'https://p16-sign-useast2a.tiktokcdn.com/tos-useast2a-avt-0068-euttp/d181e1160df414ce0a88af957cd9b456~tplv-tiktokx-cropcenter:300:300.jpeg?dr=14577&nonce=93378&refresh_token=cc332eb16e34436bb0652fb122dce686&x-expires=1741878000&x-signature=V7Ve7VHx2tMbd5Q13BSpSsVAvRk%3D&idc=maliva&ps=13740610&shcp=d05b14bd&shp=45126217&t=4d5b0474'}, 'is_top': 0}]

# %%
responses = []
responses.extend(data)

# Ensure the 'data' directory exists
os.makedirs("data", exist_ok=True)

# Path to the JSON file
file_path = "data/tiktok_trending.json"

# Load existing data or initialize structure
if os.path.exists(file_path) and os.path.getsize(file_path) > 0:
    with open(file_path, "r", encoding="utf-8") as f:
        file_data = json.load(f)
else:
    file_data = []  # Default structure if file is empty/missing
    
responses.extend(file_data)

# Save to a JSON file
with open(file_path, "w", encoding="utf-8") as f:
    json.dump(responses, f, indent=4, ensure_ascii=False)

# %%
with open(file_path, "r", encoding="utf-8") as f:
    data = json.load(f)
    print(data)
# Out:
# [{'aweme_id': 'v24044gl0000cum6hp7og65ijef92k7g', 'video_id': '7470462714754731286', 'region': 'GB', 'title': 'Gym video 💪#gym #uk #mzaidyt❤ #usa #tableeghijumat #viral #treanding #pyf ', 'cover': 'https://p16-pu-sign-no.tiktokcdn-eu.com/tos-no1a-p-0037-no/oUQYjNekPQIZIHLK1DWL49HIQpGFbdAFJAeeJn~tplv-tiktok-shrink:640:640.jpeg?dr=14571&nonce=71724&refresh_token=6d40c6c1427cd1ae968fd5a0797811f7&x-expires=1741878000&x-signature=G3tknnu5DP6%2FV3UP2vqIBTClads%3D&idc=maliva&ps=13740610&s=FEED&shcp=34ff8df6&shp=d05b14bd&t=4d5b0474', 'ai_dynamic_cover': 'https://p16-pu-sign-no.tiktokcdn-eu.com/tos-no1a-p-0037-no/oUQYjNekPQIZIHLK1DWL49HIQpGFbdAFJAeeJn~tplv-tiktok-shrink:640:640.jpeg?dr=14571&nonce=71724&refresh_token=6d40c6c1427cd1ae968fd5a0797811f7&x-expires=1741878000&x-signature=G3tknnu5DP6%2FV3UP2vqIBTClads%3D&idc=maliva&ps=13740610&s=FEED&shcp=34ff8df6&shp=d05b14bd&t=4d5b0474', 'origin_cover': 'https://p16-pu-sign-no.tiktokcdn-eu.com/tos-no1a-p-0037-no/o4IG8Gx9IaeEgSLAPfQApqNebHKjDJIWxgLinF~tplv-tiktokx-360p.webp?dr=14555&nonce=66960&refresh_token=393cb13f03be150b597a47f0803632ea&x-expires=1741878000&x-signature=S2sIkawdbduAs9IGMsquigOzg2Y%3D&ftpl=1&idc=maliva&ps=13740610&s=FEED&shcp=34ff8df6&shp=d05b14bd&t=4d5b0474', 'duration': 142, 'play': 'https://v16m-default.akamaized.net/3833644289a527c8609c7ee94ed07295/67d1f81c/video/tos/no1a/tos-no1a-ve-0068-no/oUeIpaFpgbKIIcWDQsEGeL8jHJALASNAfj2PRn/?a=30192&bti=OHYpOTY0Zik3OjlmOm01MzE6ZDQ0MDo%3D&ch=0&cr=13&dr=0&er=0&lr=all&net=0&cd=0%7C0%7C0%7C&cv=1&br=1798&bt=899&cs=0&ds=6&ft=XE5bCqT0mmjPD120kXTJ3wUp5jB7EeF~O5&mime_type=video_mp4&qs=0&rc=OzM7OmVoOTVnNTs3ZmRnNEBpam48aGw5cnM5eDMzbzczNUAxYTYwXy5hXmAxNDBhX2EyYSM0L2NnMmQ0ZWpgLS1kMTFzcw%3D%3D&vvpl=1&l=2025031215072440B458E665B13A0B5FD1&btag=e00090000', 'wmplay': 'https://v16m-default.akamaized.net/6b0789c83d9b92c378ce8967a13b338b/67d1f81c/video/tos/no1a/tos-no1a-ve-0068c001-no/oYZQBZ6Sx5B7ionIQosm6ByPERaEAPiYZZU5U/?a=30192&bti=OHYpOTY0Zik3OjlmOm01MzE6ZDQ0MDo%3D&ch=0&cr=13&dr=0&er=0&lr=all&net=0&cd=0%7C0%7C0%7C&cv=1&br=1876&bt=938&cs=0&ds=3&ft=XE5bCqT0mmjPD120kXTJ3wUp5jB7EeF~O5&mime_type=video_mp4&qs=0&rc=ODVkODU8Omk5aWQ6OTg1aEBpam48aGw5cnM5eDMzbzczNUAxNTBhXy4tNV4xLjZfLl8uYSM0L2NnMmQ0ZWpgLS1kMTFzcw%3D%3D&vvpl=1&l=2025031215072440B458E665B13A0B5FD1&btag=e00090000', 'size': 16408401, 'wm_size': 17109570, 'music': '', 'music_info': {'id': '7183714413009406746', 'title': 'original sound - bakht.7', 'play': '', 'cover': 'https://p16-sign-useast2a.tiktokcdn.com/tos-useast2a-avt-0068-giso/448342aef25fcc6335b2554cd2214995~tplv-tiktokx-cropcenter:1080:1080.jpeg?dr=14579&nonce=98236&refresh_token=afe4355cf1c820971343bc1e1e2a2fc0&x-expires=1741878000&x-signature=GExOJJQ76k3kpi9wn6dxA8iy0lI%3D&idc=maliva&ps=13740610&shcp=d05b14bd&shp=45126217&t=4d5b0474', 'author': '🥀', 'original': True, 'duration': 443, 'album': ''}, 'play_count': 19306352, 'digg_count': 1818407, 'comment_count': 56711, 'share_count': 39129, 'download_count': 30007, 'create_time': 1739352649, 'anchors': None, 'anchors_extras': '', 'is_ad': False, 'commerce_info': {'adv_promotable': False, 'branded_content_type': 0}, 'commercial_video_info': '', 'item_comment_settings': 0, 'mentioned_users': '', 'author': {'id': '7270758105071502368', 'unique_id': '0ur_vinse', 'nickname': 'ourvinse fanpage', 'avatar': 'https://p16-sign-useast2a.tiktokcdn.com/tos-useast2a-avt-0068-euttp/d181e1160df414ce0a88af957cd9b456~tplv-tiktokx-cropcenter:300:300.jpeg?dr=14577&nonce=93378&refresh_token=cc332eb16e34436bb0652fb122dce686&x-expires=1741878000&x-signature=V7Ve7VHx2tMbd5Q13BSpSsVAvRk%3D&idc=maliva&ps=13740610&shcp=d05b14bd&shp=45126217&t=4d5b0474'}, 'is_top': 0}, {'aweme_id': '', 'video_id': '7477584774253563158', 'region': 'GB', 'title': 'null', 'cover': 'https://p16-pu-sign-no.tiktokcdn-eu.com/tos-no1a-i-photomode-no/0e09d99f9278497f8d3fff74bad96747~tplv-photomode-image-v1:q70.webp?dr=14555&from=photomode.FEED&ftpl=1&idc=maliva&nonce=70803&ps=13740610&refresh_token=bd6525529d020fde4710810bd3936d2b&s=FEED&s ...

# %%
df = pd.json_normalize(data, sep="_")

df['create_time'] = pd.to_datetime(df['create_time'], unit='s')

features = ['aweme_id', 'video_id', 'region', 'title', 'duration', 'music', 'music_info_author', 'music_info_original',
       'music_info_duration', 'music_info_album', 'play_count', 'digg_count', 'comment_count',
       'share_count', 'download_count', 'create_time','is_ad', 'mentioned_users', 'author_unique_id', 'author_nickname', 'images']

df_features = df[features]

df_features
# Out:
#                            aweme_id             video_id region  \
# 0  v24044gl0000cum6hp7og65ijef92k7g  7470462714754731286     GB
# 1                                    7477584774253563158     GB
# 2                                    7479587219754290454     GB
# 3  v24044gl0000cum6hp7og65ijef92k7g  7470462714754731286     GB
# 4  v0f044gc0000cum1s7nog65qhv6d12r0  7470379347623316768     GB
# 5  v0f044gc0000ctv5ngnog65jj1tlvrdg  7457499579240566048     GB
# 6  v24044gl0000cum6hp7og65ijef92k7g  7470462714754731286     GB
# 7  v14044g50000cv643jfog65rpo4o05bg  7479425720670899464     GB
# 8                                    7478729697988349207     GB
# 9  v24025gl0000cv788hfog65i3pjei8jg  7480061196939431190     GB
#
#                                                title  duration music  \
# 0  Gym video 💪#gym #uk #mzaidyt❤ #usa #tableeghij...       142
# 1                                               null         0
# 2  خدا اور اس کے فرشتے آپ ﷺ پر درود بھیجتے ہیں۔ ا...         0
# 3  Gym video 💪#gym #uk #mzaidyt❤ #usa #tableeghij...       142
# 4  #CapCut #misswow💦 #1mviews🥹 #likeproblem🥹 #30k...         9
# 5  Baby fighting like Jackie Chan/ Video generate...         5
# 6  Gym video 💪#gym #uk #mzaidyt❤ #usa #tableeghij...       142
# 7                        #ujalakhanzadi #🥰🥰🥰🥰❤️❤️❤️         15
# 8  #islamabadbeautyofpakistan #Islamabad #islamic...         0
# 9  Magical Frame mein Sab Golmal hai 🤣🥲 (Part 1) ...        70
#
#    music_info_author music_info_original  music_info_duration  \
# 0                  🥀                True                  443
# 1    ㋛💔𐌁🆁𐌏𐌊𐌄🅽💔Ⱡ🅸₣Ɇ🥀㋛                true                   14
# 2     Muhammad Awais                true                   61
# 3                  🥀                true                  443
# 4             *مغل*💀                True                   14
# 5              AloAI                True                    5
# 6                  🥀                True                  443
# 7  𝐁𝐚𝐢𝐭 𝐮𝐥 𝐃𝐚𝐰𝐚𝐡 🖤🕊️                True                   25
# 8   L()\/E ¡$ L¡FE 💞                True                  231
# 9              UK TV                True                   70
#
#   music_info_album  ...  digg_count  comment_count  share_count  \
# 0                   ...     1818407          56711        39129
# 1                   ...         153             17          145
# 2                   ...        2823             32          336
# 3                   ...     1818371          56711        39129
# 4                   ...      296757           5551        18617
# 5                   ...      803730          15059       380218
# 6                   ...     1818372          56711        39129
# 7                   ...       78948           2157         1400
# 8                   ...       15069             44          608
# 9                   ...       44930            312          363
#
#    download_count         create_time  is_ad      mentioned_users  \
# 0           30007 2025-02-12 09:30:49  False
# 1              15 2025-03-03 14:08:03  false
# 2             208 2025-03-08 23:38:33  false
# 3           30006 2025-02-12 09:30:49  false
# 4            9834 2025-02-12 04:07:24  False
# 5         1386401 2025-01-08 11:07:17  False  7423680591752184878
# 6           30006 2025-02-12 09:30:49  False
# 7              84 2025-03-08 13:11:48  False
# 8              10 2025-03-06 16:10:55  False
# 9             459 2025-03-10 06:18:49  False
#
#    author_unique_id      author_nickname  \
# 0         0ur_vinse     ourvinse fanpage
# 1      mirzadani198              Dani271
# 2  muhammadamir.719        ❤️محمد عامر❤️
# 3         0ur_vinse     ourvinse fanpage
# 4      babaroffice5  HYPER SHAAN 😎❤️‍🔥🇵🇰
# 5           aloai07                AloAI
# 6         0ur_vinse     ourvinse fanpage
# 7     ujalakhanzade        ujalakhanzade
# 8  islamicreels800k     islamicreels800k
# 9          uktv_fun                UK TV
#
#                                               images
# 0                                                NaN
# 1  [https://p16-pu-sign-no.tiktokcdn-eu.com/tos-n...
# 2  [https://p16-pu-sign-no.tiktokcdn-eu.com/tos-n...
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8  [https://p16-pu-sign-no.tiktokcdn-eu.com/tos-n...
# 9                                                NaN
#
# [10 rows x 21 columns]

# %%
df.to_csv('data/tiktok_trending_features.csv', index = False)
